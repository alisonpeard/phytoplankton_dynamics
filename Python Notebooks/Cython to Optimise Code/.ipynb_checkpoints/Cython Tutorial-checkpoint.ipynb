# %% [markdown]
# [Link to Tutorial](https://cython.readthedocs.io/en/latest/src/tutorial/cython_tutorial.html)
#
#     from distutils.core import setup
#     from Cython.Build import cythonize
#
#     setup(
#         ext_modules = cythonize("equations.pyx")
#     )
#
#     $ python setup.py build_ext --inplace

# %%
import equations

# %%
equations.get_stationary()
# Out:
# (array([546.86159737, 559.13216178, 568.60077515, 575.40547515,
#         579.72349688, 581.76318539, 581.75425183, 579.93734397,
#         576.55400303, 571.83794299, 566.00827618, 559.2649273 ,
#         551.78613891, 543.72773938, 535.22373724, 526.38780054,
#         517.31523935, 508.08519702, 498.76284547, 489.40145708,
#         480.04428377, 470.72621485, 461.47520988, 452.31351865,
#         443.25870734, 434.32451402, 425.52155662, 416.85791575,
#         408.33961257, 399.97099931, 391.755078  , 383.6937601 ,
#         375.78807796, 368.03835694, 360.44435565, 353.00538013,
#         345.72037707, 338.58800977, 331.60672033, 324.77478043,
#         318.090333  , 311.55142634, 305.15604221, 298.90211891,
#         292.78757027, 286.81030138, 280.96822155, 275.25925511,
#         269.68135028, 264.23248667, 258.91068145, 253.71399458,
#         248.6405332 , 243.68845536, 238.85597314, 234.14135544,
#         229.54293033, 225.05908709, 220.68827812, 216.42902061,
# ...

# %%
import numpy as np
import equations
from equations import get_stationary
from equations import get_time_evolution
from equations import get_R
import matplotlib.pyplot as plt

# inital parameters
zmax = 30
tmax = 100
z_steps = int(zmax*10) # dz = 0.1
column_depth = np.arange(1,zmax+1,1)

# Define results matrices
stationary_A = np.zeros((z_steps,zmax)) 
stationary_Rb = np.zeros((z_steps,zmax))
stationary_Rd = np.zeros((z_steps,zmax))
stationary_Rs = np.zeros(zmax)
stationary_Rb.shape
# Out:
# (300, 30)

# %% [markdown]
# # Turbulence-Depth Plots
# ## d=1.0

# %%
d = 1.0
I_0 = 300.0

i = 0
for depth in column_depth:
    depth_steps = depth*10 # because dz=0.1 there are 10 times more steps than the depth
    stationary_A[:depth_steps,i], stationary_Rb[:depth_steps,i], stationary_Rd[:depth_steps,i], stationary_Rs[i] = get_stationary(zmax=depth,tmax=tmax, d=d, I0=I_0)
    i += 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.DataFrame(stationary_A).head()
# Out:
#            0           1           2           3           4           5   \
# 0  216.753525  359.424676  373.617561  364.935936  365.950294  445.885686
# 1  221.860931  367.958355  382.409982  373.480140  374.482923  456.108176
# 2  226.345473  375.588157  390.106367  380.865955  381.783295  464.481359
# 3  230.206075  382.337011  396.734624  387.119792  387.878779  471.067753
# 4  233.444514  388.235153  402.332103  392.277851  392.807316  475.950488
#
#            6           7           8           9   ...          20  \
# 0  500.704861  526.783519  540.037284  546.861597  ...  543.443726
# 1  512.052107  538.655166  552.172776  559.132162  ...  555.642747
# 2  521.058601  547.930932  561.577387  568.600775  ...  565.067621
# 3  527.822983  554.730620  568.382754  575.405475  ...  571.853526
# 4  532.473727  559.208972  572.758229  579.723497  ...  576.174219
#
#            21          22          23          24          25          26  \
# 0  542.956881  542.580164  542.291072  542.069841  541.900201  541.769364
# 1  555.146160  554.761909  554.467038  554.241385  554.068355  553.934904
# 2  564.566152  564.178135  563.880380  563.652524  563.477806  563.343054
# 3  571.351580  570.963213  570.665202  570.437155  570.262293  570.127431
# 4  575.675646  575.289916  574.993943  574.767464  574.593808  574.459877
#
#            27          28          29
# 0  541.667611  541.587723  541.524417
# 1  553.831117  553.749633  553.685062
# 2  563.238256  563.155977  563.090777
# 3  570.022547  569.940201  569.874948
# 4  574.355717  574.273940  574.209138
#
# [5 rows x 30 columns]

# %%
# Heatmap
plt.imshow(stationary_A[:,:],aspect=1,origin="lower",extent=(0,zmax,0,zmax))
plt.xlabel('water column depth (m)')
plt.ylabel('water depth (m)')
plt.title('A concentration for d = {}'.format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %% [markdown]
# ### Create Visuals for R

# %%
R = get_R(Rd,Rb)

# %%
# Heatmap
plt.imshow(R[:,:],aspect=1,origin="lower",extent=(0,zmax,0,zmax),vmax=50)
plt.xlabel('water column depth (m)')
plt.ylabel('water depth (m)')
plt.title('R concentration for d = {}'.format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
# save everything to results dataframes to save repeating
pd.DataFrame(stationary_A).to_csv("A_d1.csv")
pd.DataFrame(stationary_Rb).to_csv("Rb_d1.csv")
pd.DataFrame(stationary_Rd).to_csv("Rd_d1.csv")
pd.DataFrame(stationary_Rs).to_csv("Rs_d1.csv")
pd.DataFrame(R).to_csv("R_d1.csv")

# %% [markdown]
# ## d = 0.1

# %%
stationary_A01 = np.zeros((z_steps,zmax)) 
stationary_Rb01 = np.zeros((z_steps,zmax))
stationary_Rd01 = np.zeros((z_steps,zmax))
stationary_Rs01 = np.zeros(zmax)

# %%
d = 0.1
i = 0
I_0 = 300.0
for depth in column_depth:
    depth_steps = depth*10
    stationary_A01[:depth_steps,i], stationary_Rb01[:depth_steps,i], stationary_Rd01[:depth_steps,i], stationary_Rs01[i] = get_stationary(zmax=depth,tmax=tmax, d=d, I0=I_0)
    i += 1

# %%
# Heatmap
plt.imshow(stationary_A01[:,:],aspect=1,origin="lower",extent=(0,zmax,0,zmax))
plt.xlabel('water column depth (m)')
plt.ylabel('water depth (m)')
plt.title('A concentration for d = {}'.format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
R01 = get_R(Rd01,Rb01)

# %%
# Heatmap
plt.imshow(R01[:,:],aspect=1,origin="lower",extent=(0,zmax,0,zmax),vmax=50)
plt.xlabel('water column depth (m)')
plt.ylabel('water depth (m)')
plt.title('R concentration for d = {}'.format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
pd.DataFrame(stationary_A01).to_csv("A_d01.csv")
pd.DataFrame(stationary_Rb01).to_csv("Rb_d01.csv")
pd.DataFrame(stationary_Rd01).to_csv("Rd_d01.csv")
pd.DataFrame(stationary_Rs01).to_csv("Rs_d01.csv")
pd.DataFrame(stationary_R01).to_csv("R_d01.csv")

# %% [markdown]
# # d = 10.0

# %%
stationary_A10 = np.zeros((z_steps,zmax)) 
stationary_Rb10 = np.zeros((z_steps,zmax))
stationary_Rd10 = np.zeros((z_steps,zmax))
stationary_Rs10 = np.zeros(zmax)

# %%
d = 10.0
i = 0
I_0 = 300.0
for depth in column_depth:
    depth_steps = depth*10
    stationary_A1[:depth_steps,i], stationary_Rb1[:depth_steps,i], stationary_Rd1[:depth_steps,i], stationary_Rs1[i] = get_stationary(zmax=depth,tmax=tmax, d=d, I0=I_0)
    i += 1

# %%
# Heatmap
plt.imshow(stationary_A1[:,:],aspect=1,origin="lower",extent=(0,zmax,0,zmax))
plt.xlabel('water column depth (m)')
plt.ylabel('water depth (m)')
plt.title('A concentration for d = {}'.format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
R10 = get_R(Rd10,Rb10)

# %%
# Heatmap
plt.imshow(R10[:,:],aspect=1,origin="lower",extent=(0,zmax,0,zmax),vmax=50)
plt.xlabel('water column depth (m)')
plt.ylabel('water depth (m)')
plt.title('R concentration for d = {}'.format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
pd.DataFrame(stationary_A10).to_csv("A_d10.csv")
pd.DataFrame(stationary_Rb10).to_csv("Rb_d10.csv")
pd.DataFrame(stationary_Rd10).to_csv("Rd_d10.csv")
pd.DataFrame(stationary_Rs10).to_csv("Rs_d10.csv")
pd.DataFrame(R10).to_csv("R_d10.csv")

# %% [markdown]
# # Time-Evolution Plots

# %%
from mpl_toolkits.mplot3d import axes3d

# %% [markdown]
# ## d = 10

# %%
d=10.0
A_d10, Rb_d10, Rd_d10, Rs_d10, z_grid, time_steps, Nz, Nt = get_time_evolution(zmax=zmax, tmax=tmax, d=d, I0=I_0)

# %%
# Visualize Shift
plt.plot(z_grid,A_d10[:,-1])
plt.plot(z_grid,A_d10[:,0],color = 'r')
plt.title('A shift for d = {}'.format(d))

# %%
# Heatmap
plt.imshow(A_d10[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.xlabel('days')
plt.ylabel('depth (meters)')
plt.title('A concentration for d = {}'.format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
#%matplotlib notebook

days = np.linspace(0,tmax,Nt)
T,Z = np.meshgrid(days,z_grid)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(T,Z, A_d10, cmap='cool')
ax.set_xlabel('time (days)')
ax.set_ylabel('z (meters)')
ax.set_zlabel('C')
ax.set_title('A - plankton for d = {}'.format(d))
# Out:
# Text(0.5, 0.92, 'A - plankton')

# %% [markdown]
# ## d = 1.0

# %%
d=1.0
A_d1, Rb_d1, Rd_d1, Rs_d1, z_grid, time_steps, Nz, Nt = get_time_evolution(zmax=zmax, tmax=tmax, d=d, I0=I_0)

# %%
# Visualize Shift
plt.plot(z_grid,A_d1[:,-1])
plt.plot(z_grid,A_d1[:,0],color = 'r')
plt.title("A shift for d = {}".format(d))

# %%
# Heatmap
plt.imshow(A_d1[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.xlabel('days')
plt.ylabel('depth (meters)')
plt.title("A concentration for d = {}".format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
#%matplotlib notebook

days = np.linspace(0,tmax,Nt)
T,Z = np.meshgrid(days,z_grid)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(T,Z, A_d1, cmap='cool')
ax.set_xlabel('time (days)')
ax.set_ylabel('z (meters)')
ax.set_zlabel('C')
ax.set_title('A - plankton for d = {}'.format(d))
# Out:
# Text(0.5, 0.92, 'A - plankton')

# %% [markdown]
# ## d = 0.1

# %%
d=0.01
A_d01, Rb_d01, Rd_d01, Rs_d01, z_grid, time_steps, Nz, Nt = equations.get_time_evolution(zmax=zmax, tmax=tmax, d=d, I0=I_0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d1b49bbda56d> in <module>
#       1 d=0.01
# ----> 2 A_d01, Rb_d01, Rd_d01, Rs_d01, z_grid, time_steps, Nz, Nt = equations.get_time_evolution(zmax=50.0, tmax=100.0, d=0.1, I0=300.0)
#
# ~/Documents/4th_Year_UCC/am4090project/Python Notebooks/equations.pyx in equations.get_time_evolution()
#     144     for t in time_steps[:-1]:
#     145
# --> 146         A_next, Rb_next, Rd_next, Rs_next = next_step(z_grid, A_next, Rb_next, Rd_next, Rs_next, dz,dt,d)
#     147
#     148         if ( i % 1000 == 0):
#
# ~/Documents/4th_Year_UCC/am4090project/Python Notebooks/equations.pyx in equations.next_step()
#      36     """Calculates next step for input arrays of length zmax"""
#      37
# ---> 38     II = I(z,A)
#      39     q = Rb[1:-1]/A[1:-1]
#      40     pp = p(II[1:-1],q)
#
# ~/Documents/4th_Year_UCC/am4090project/Python Notebooks/equations.pyx in equations.I()
#      22     """Function to plot I using array A[:,i], default k=0.0003, larger values of k make effect of A on I more apparent"""
#      23     integral = np.zeros(len(z))
# ---> 24     integral[1:] = np.cumsum(k*A[1:])
#      25     return I_0 * np.exp( - integral- kbg*z)
#      26
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in cumsum(a, axis, dtype, out)
#    2250
#    2251
# -> 2252 @array_function_dispatch(_cumsum_dispatcher)
#    2253 def cumsum(a, axis=None, dtype=None, out=None):
#    2254     """
#
# KeyboardInterrupt:

# %%
# Visualize Shift
plt.plot(z_grid,A_d01[:,-1])
plt.plot(z_grid,A_d01[:,0],color = 'r')
plt.title("A shift for d = {}".format(d))

# %%
# Heatmap
plt.imshow(A_d01[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.xlabel('days')
plt.ylabel('depth (meters)')
plt.title("A concentration for d = {}".format(d))
plt.gca().invert_yaxis()
plt.colorbar()

# %%
#%matplotlib notebook

days = np.linspace(0,tmax,Nt)
T,Z = np.meshgrid(days,z_grid)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(T,Z, A_d01, cmap='cool')
ax.set_xlabel('time (days)')
ax.set_ylabel('z (meters)')
ax.set_zlabel('C')
ax.set_title("A concentration for d = {}".format(d))
# Out:
# Text(0.5, 0.92, 'A - plankton')

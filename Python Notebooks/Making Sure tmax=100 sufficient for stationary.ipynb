# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from my_equations import get_time_evolution

# %%
tmax = 1000.0
zmax=30.0
d=1.0
A, Rb, Rd, Rs, z_grid, time_steps, Nz, Nt = get_time_evolution(zmax=zmax, tmax=tmax, d=d, I0=300.0, dz=0.1,dt_ratio=1/1000)

# %%
# 3D Visualize
# %matplotlib notebook
days = np.linspace(0,tmax,Nt)
T,Z = np.meshgrid(days,z_grid)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(T,Z, A, cmap='cool')
ax.set_xlabel('time (days)')
ax.set_ylabel('z (meters)')
ax.set_zlabel('C')
ax.set_title('A - Phytoplankton for d = {}'.format(d))
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 0.92, 'A - Phytoplankton for d = 1.0')

# %%
from my_equations import get_R
R = get_R(Rd,Rb)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(T,Z, R, cmap='cool')
ax.set_xlabel('time (days)')
ax.set_ylabel('z (meters)')
ax.set_zlabel('C')
ax.set_title('R - Nutrients for d = {}'.format(d))
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 0.92, 'R - Nutrients for d = 1.0')

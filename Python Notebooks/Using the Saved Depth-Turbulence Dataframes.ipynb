# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# %% [markdown]
# # Plots for d=0.1

# %%
A_01 = pd.read_csv("Results DataFrames/A_d01.csv",header=None).iloc[1:,1:]
Rb_01 = pd.read_csv("Results DataFrames/Rb_d01.csv",header=None).iloc[1:,1:]
Rd_01 = pd.read_csv("Results DataFrames/Rd_d01.csv",header=None).iloc[1:,1:]

A_01 = A_01.to_numpy()
Rb_01 = Rb_01.to_numpy()
Rd_01 = Rd_01.to_numpy()

tmax = 100
zmax = A_01.shape[1]

# iterate through rows
R_01 = np.zeros(Rd_01.shape)
for i in range(len(Rd_01)):
   # iterate through columns
   for j in range(len(Rd_01[0])):
        R_01[i,j] = Rd_01[i,j] + Rb_01[i,j]

# %%
plt.imshow(A_01[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("A concentration for d=0.1")
plt.xlabel('water column depth (metres)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()

# %%
R_01 = pd.read_csv("Results DataFrames/R_d01.csv",header=None).iloc[1:,1:]
R_01 = R_01.to_numpy()

# %%
## not the right one, need to run again to get R_01 dataframe for tmax=400
plt.imshow(R_01[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("R concentration for d=0.1")
plt.xlabel('water column depth (metres)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()

# %% [markdown]
# # Plots for d=1.0

# %%
A_1 = pd.read_csv("Results DataFrames/A_d1.csv",header=None).iloc[1:,1:]
Rb_1 = pd.read_csv("Results DataFrames/Rb_d1.csv",header=None).iloc[1:,1:]
Rd_1 = pd.read_csv("Results DataFrames/Rd_d1.csv",header=None).iloc[1:,1:]

A_1 = A_1.to_numpy()
Rb_1 = Rb_1.to_numpy()
Rd_1 = Rd_1.to_numpy()

tmax = 100
zmax = A_1.shape[1]

# iterate through rows
R_1 = np.zeros(Rd_1.shape)
for i in range(len(Rd_1)):
   # iterate through columns
   for j in range(len(Rd_01[0])):
        R_1[i,j] = Rd_1[i,j] + Rb_1[i,j]

# %%
plt.imshow(A_1[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("A concentration for d=1.0")
plt.xlabel('water column depth (metres)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()

# %%
# %matplotlib notebook 
# Visualize 3D 
Nz = int(zmax/0.1)
depths = np.linspace(0,zmax,zmax)
z_grid = np.linspace(0,zmax,Nz)
T,Z = np.meshgrid(depths,z_grid)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(T,Z, A_1, cmap='cool')
ax.set_xlabel('water column depth (m)')
ax.set_ylabel('z (meters)')
ax.set_zlabel('C')
ax.set_title('A - Phytoplankton for d = {}'.format(10))
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 0.92, 'A - Phytoplankton for d = 10')

# %%
plt.imshow(R_1[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("R concentration for d=1.0")
plt.xlabel('water column depth (metres)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()

# %% [markdown]
# # Plots for d=10.0

# %%
A_10 = pd.read_csv("Results DataFrames/A_d10.csv",header=None).iloc[1:,1:]
Rb_10 = pd.read_csv("Results DataFrames/Rb_d10.csv",header=None).iloc[1:,1:]
Rd_10 = pd.read_csv("Results DataFrames/Rd_d10.csv",header=None).iloc[1:,1:]

A_10 = A_10.to_numpy()
Rb_10 = Rb_10.to_numpy()
Rd_10 = Rd_10.to_numpy()

tmax = 100
zmax = A_10.shape[1]

# iterate through rows
R_10 = np.zeros(Rd_10.shape)
for i in range(len(Rd_10)):
   # iterate through columns
   for j in range(len(Rd_10[0])):
        R_10[i,j] = Rd_10[i,j] + Rb_10[i,j]

# %%
plt.imshow(A_10[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("A concentration for d=10.0")
plt.xlabel('water column depth (metres)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()

# %%
A_10.shape
# Out:
# (300, 30)

# %%
# %matplotlib notebook 
# Visualize 3D 
Nz = int(zmax/0.1)
depths = np.linspace(0,zmax,zmax)
z_grid = np.linspace(0,zmax,Nz)
T,Z = np.meshgrid(depths,z_grid)

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(T,Z, A_10, cmap='cool')
ax.set_xlabel('water column depth (m)')
ax.set_ylabel('z (meters)')
ax.set_zlabel('C')
ax.set_title('A - Phytoplankton for d = {}'.format(10))
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 0.92, 'Rb - Bound Nutrients for d = 10')

# %%
plt.imshow(R_10[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("R concentration for d=10.0")
plt.xlabel('water column depth (metres)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()

# %% [markdown]
# # Plots for d = 100.0

# %%
A_100 = pd.read_csv("Results DataFrames/A_d100.csv",header=None).iloc[1:,1:]
Rb_100 = pd.read_csv("Results DataFrames/Rb_d100.csv",header=None).iloc[1:,1:]
Rd_100 = pd.read_csv("Results DataFrames/Rd_d100.csv",header=None).iloc[1:,1:]

A_100 = A_100.to_numpy()
Rb_100 = Rb_100.to_numpy()
Rd_100 = Rd_100.to_numpy()

tmax = 100
zmax = A_100.shape[1]

plt.imshow(A_100[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("A concentration for d=0.1")
plt.xlabel('water column depth (meters)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()

# %%
R_100 = pd.read_csv("Results DataFrames/R_d01.csv",header=None).iloc[1:,1:]
R_100 = R_100.to_numpy()

## not the right one, need to run again to get R_100 dataframe for tmax=400
plt.imshow(R_100[:,:],aspect=tmax/zmax,origin="lower",extent=(0,tmax,0,zmax))
plt.title("R concentration for d=0.1")
plt.xlabel('water column depth (meters)')
plt.ylabel('depth (meters)')
plt.gca().invert_yaxis()
plt.colorbar()
